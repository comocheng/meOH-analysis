# %%
import pandas as pd
import numpy as np
import csv

# %%
txt_file = r"/work/westgroup/ChrisB/meOH-synthesis_cantera/meOH-synthesis/cantera_simulations/RMG_wDeut/2021_5_5_1342_199260_fixed_typo_in_Cu111_library_for_a5_nasa_parameter/IdealGasReactor/energy_off/sensitivity_off/400/csp/CSP_Spinning_basket_area_0.0231_energy_off_temp_400_h2_0_5_COCO2_0_1.dat"
csv_file = r"/work/westgroup/ChrisB/meOH-synthesis_cantera/meOH-synthesis/cantera_simulations/RMG_wDeut/2021_5_5_1342_199260_fixed_typo_in_Cu111_library_for_a5_nasa_parameter/IdealGasReactor/energy_off/sensitivity_off/400/csp/CSP_Spinning_basket_area_0.0231_energy_off_temp_400_h2_0_5_COCO2_0_1.dat"

df = pd.read_csv(csv_file,delimiter='\t')
df = df.head(200)
np.savetxt(txt_file, df, delimiter='\t')
# df.to_csv(txt_file, sep='\t')

# %%
df
# Out:
#      iter     t    dt    Density[kg/m3]    Pressure[Pascal]   \
# 0      0.0   0.1   0.1         50.763101        7.599375e+06
# 1      1.0   0.2   0.1         50.769732        7.599375e+06
# 2      2.0   0.3   0.1         50.776003        7.599375e+06
# 3      3.0   0.4   0.1         50.781935        7.599375e+06
# 4      4.0   0.5   0.1         50.787546        7.599375e+06
# ..     ...   ...   ...               ...                 ...
# 195  195.0  19.6   0.1         50.885623        7.599375e+06
# 196  196.0  19.7   0.1         50.885623        7.599375e+06
# 197  197.0  19.8   0.1         50.885623        7.599375e+06
# 198  198.0  19.9   0.1         50.885624        7.599375e+06
# 199  199.0  20.0   0.1         50.885624        7.599375e+06
#
#       Temperature[K]    N2    Ne     H2(2)     CO(3)   ...    HCOO*(17)   \
# 0               400.0   0.0   0.0  0.499940  0.049932  ...  1.255400e-12
# 1               400.0   0.0   0.0  0.499883  0.049869  ...  1.272374e-12
# ...
